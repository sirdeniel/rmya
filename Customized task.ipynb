# %%
# Name: HUGO ENRIQUE LUGMANIA MONTESDEOCA
# Part 1
# Some of the libraries we will be using 
import numpy as np
import matplotlib as mpl
import scipy as sp

# %% [markdown]
# # Homogeneous Transformation

# %%
# 8. Create a function that builds a HT matrix based on a given R and p

# %%
# 9. Is it orthogonal? Prove it

# %%
# 10. Refer to the "Example" slide of the lecture
# {R} is at a distance of 5 m of {O} and went through a rotation of 30 deg in Z 
# {C} is rotated 30 deg in Z wrt {R} and at a vertical (Z) distance of 0.5 m
# The position vector of object {B} wrt {C} is [[-2],[6],[6]] 
# Obtain the position vector of {B} wrt {O} using the functions you created

# %%
# 11. Plot the vector you obtained in a 3d fig

# %%
# hint:
# (modify as preferable) 
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0,1], [0,1], [0,2], label='curve')
ax.legend()
ax.set_xlabel('X ')
ax.set_ylabel('Y ')
ax.set_zlabel('Z ')

plt.show()

# %% [markdown]
# # Research hours test

# %%
# Show the quaternion equation for rotation around an axis in the angle form (clue: search for 3blue1brown)

# %%
# Explain what the elements do and how do they behave for rotation

# %%
# If theta angle changes and q doesn´t, what happens? Explain briefly
